# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, classification_report, mean_squared_error, mean_absolute_error, r2_score


# Đọc dữ liệu từ tệp CSV
data = pd.read_csv('/content/drive/MyDrive/Cao Học/Phương pháp NCKH - Cao Văn Kiên/Cuối Kỳ/Model/data/diabetes.csv')

# Chọn các đặc trưng và nhãn
features = data.drop('Outcome', axis=1)
labels = data['Outcome']

# Chia dữ liệu thành tập huấn luyện và tập kiểm tra
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.2, random_state=42)

# Xây dựng mô hình Random Forest
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

# Dự đoán nhãn trên tập kiểm tra
y_pred = model.predict(X_test)

# Đánh giá mô hình
accuracy = accuracy_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print("Đánh giá mô hình Random Forest:")
print(classification_report(y_test, y_pred))
print("Accuracy mô hình RF:", accuracy)
print("Mean Squared Error (MSE) mô hình RF:", mse)
print("Root Mean Squared Error (RMSE) mô hình RF:", rmse)
print("R2 Score mô hình RF:", r2)
# Out:
# Đánh giá mô hình Random Forest:
#               precision    recall  f1-score   support
#
#            0       0.79      0.78      0.78        99
#            1       0.61      0.62      0.61        55
#
#     accuracy                           0.72       154
#    macro avg       0.70      0.70      0.70       154
# weighted avg       0.72      0.72      0.72       154
#
# Accuracy mô hình RF: 0.7207792207792207
# Mean Squared Error (MSE) mô hình RF: 0.2792207792207792
# Root Mean Squared Error (RMSE) mô hình RF: 0.5284134548067254
# R2 Score mô hình RF: -0.21616161616161644
